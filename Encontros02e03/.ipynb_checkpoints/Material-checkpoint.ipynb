# %% [markdown]
# <div style="background-color: #fff1cd; background-image: url('../socnet.svg'); background-position: 1em 1em; background-repeat: no-repeat; background-size: 3em 3em; box-shadow: 0 0 0.25em 0; color: #403c33; font-weight: bold; min-height: 3em; padding: 1em 1em 1em 5em;">Como o nome sugere, você deve usar este notebook como um *caderno de anotações*. Use as células editáveis para tomar notas, principalmente quando os professores estiverem complementando o conteúdo com exposições orais ou exposições na lousa. Crie um *fork* pessoal do repositório, faça *commits* dessas notas e puxe do *upstream* sempre que o repositório for atualizado. Se alguma atualização modificar um notebook existente, essa modificação não envolverá as células editáveis, portanto não causará conflito.</div>

# %% [markdown]
# # Redes Sociais: Material do Encontro 3
#
# Bem-vindo! Ao final desta atividade, você deverá ser capaz de:
#
# * usar a biblioteca Seaborn para visualizar relações entre dados;
# * usar a biblioteca SciPy para calcular coeficientes de correlação clássicos;
# * usar a biblioteca SciPy para realizar testes de não-correlação clássicos.
#
# Esta atividade deve ser realizada em *dupla* ou *trio*, pois o processo de discussão é importante.

# %%
# Configura caminho dos módulos.
import sys
sys.path.append('..')

# Importa módulos não-padrão.
from scipy.stats import kendalltau, pearsonr, spearmanr
import pandas as pd
import seaborn as sns

# Importa módulos próprios.
import socnet as sn
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Vamos carregar novamente a rede de citações do Encontro 1.

# %%
g = sn.load_graph('../Encontro01/entrada.gml')

# %% [markdown]
# Vamos também construir um *data frame* com as seguintes colunas:
# * *qualities*: qualidade intrínseca;
# * *degrees*: quantidade de citações recebidas ou feitas;
# * *indegrees*: quantidade de citações recebidas;
# * *outdegrees*: quantidade de citações feitas.

# %%
data = pd.DataFrame.from_dict({
    'qualities': [g.nodes[n]['quality'] for n in g.nodes],
    'degrees': [g.degree(n) for n in g.nodes],
    'indegrees': [g.in_degree(n) for n in g.nodes],
    'outdegrees': [g.out_degree(n) for n in g.nodes],
})

# %% [markdown]
# Agora vamos visualizar as relações entre esses dados.

# %%
sns.pairplot(data);

# %% [markdown]
# **Antes de rodar a próxima célula, estime qual você acha que seria o coeficiente de correlação para cada linha e cada coluna.**

# %% [raw]
# degree/quality E indegree/quality : mostram que a relação qualidade e citaçoes recebidas possui baixa correlação, e nao é diretamente proporcional, o que teoricamente deveria ser, pois melhores artigos deveriam receber mais citações.
#
# Outdegree + todos os outros: mostra que é sempre parecida entre os autores a quantidade de menções que um autor faz em seu artigo, variando entre 8, 9 e 10. Ou seja, todos os graficos serem lineares e constantes fazem sentido.
#
# Indegree/degree: Essa faz sentido ser crescente e diretamente proporcional, com alta correlação, pois o degree é uma juncao do out com o in, e como o out é constante, quanto maior o in, maior a taxa de degree

# %% [markdown]
# Por fim, vamos calcular diferentes coeficientes de correlação e os *p-values* relativos ao teste da hipótese nula de que não existe correlação.

# %%
def test_pearson(x, y):
    return pearsonr(x, y)


def test_spearman(x, y):
    result = spearmanr(x, y)

    return result.correlation, result.pvalue


def test_kendall(x, y):
    result = kendalltau(x, y)

    return result.correlation, result.pvalue


columns = list(data)

for x in columns:
    for y in columns:
        if x != y:
            print('{} x {}'.format(x, y))

            for test in [test_pearson, test_spearman, test_kendall]:
                correlation, pvalue = test(data[x], data[y])

                print('  {}: correlation {}, pvalue {}'.format(test.__name__, correlation, pvalue))
# Out:
# qualities x degrees
#   test_pearson: correlation 0.20594030425026116, pvalue 0.039821000162764575
#   test_spearman: correlation 0.18339430772585819, pvalue 0.06778861968009063
#   test_kendall: correlation 0.12741802589161824, pvalue 0.06553053658086685
# qualities x indegrees
#   test_pearson: correlation 0.2068858458108394, pvalue 0.03889953929942277
#   test_spearman: correlation 0.2107637777926036, pvalue 0.03530482532635664
#   test_kendall: correlation 0.14750864333780078, pvalue 0.034217191033083745
# qualities x outdegrees
#   test_pearson: correlation -0.019769364688923433, pvalue 0.8452150766406086
#   test_spearman: correlation -0.02558774746281504, pvalue 0.8004986342186674
#   test_kendall: correlation -0.02100273298733517, pvalue 0.7878518522071178
# degrees x qualities
#   test_pearson: correlation 0.20594030425026116, pvalue 0.039821000162764575
#   test_spearman: correlation 0.18339430772585819, pvalue 0.06778861968009063
#   test_kendall: correlation 0.12741802589161824, pvalue 0.06553053658086685
# degrees x indegrees
#   test_pearson: correlation 0.9963379231362123, pvalue 1.741384266053293e-106
#   test_spearman: correlation 0.9835154099091382, pvalue 1.3288137914624737e-74
#   test_kendall: correlation 0.941363570119477, pvalue 4.603476206016364e-40
# degrees x outdegrees
#   test_pearson: correlation 0.0005322930494152855, pvalue 0.9958063319499435
#   test_spearman: correlation 0.06161499129956993, pvalue 0.5425360962877253
#   test_kendall: correlation 0.05095829070320786, pvalue 0.5221699660374175
# indegrees x qualities
#   test_pearson: correlation 0.2068858458108394, pvalue 0.03889953929942277
#   test_spearman: correlation 0.2107637777926036, pvalue 0.03530482532635664
#   test_kendall: correlation 0.14750864333780078, pvalue 0.034217191033083745
# indegrees x degrees
#   test_pearson: correlation 0.9963379231362123, pvalue 1.741384266053293e-106
#   test_spearman: correlation 0.9835154099091382, pvalue 1.3288137914624737e-74
#   test_kendall: correlation 0.9413635701194771, pvalue 4.603476206016364e-40
# indegrees x outdegrees
#   test_pearson: correlation -0.08497252666375642, pvalue 0.40059235530633464
#   test_spearman: correlation -0.07797106321133546, pvalue 0.44065793967583056
#   test_kendall: correlation -0.061066493930631974, pvalue 0.44624725487791894
# outdegrees x qualities
#   test_pearson: correlation -0.019769364688923433, pvalue 0.8452150766406086
#   test_spearman: correlation -0.02558774746281504, pvalue 0.8004986342186674
#   test_kendall: correlation -0.02100273298733517, pvalue 0.7878518522071178
# outdegrees x degrees
#   test_pearson: correlation 0.0005322930494152855, pvalue 0.9958063319499435
#   test_spearman: correlation 0.06161499129956993, pvalue 0.5425360962877253
#   test_kendall: correlation 0.05095829070320786, pvalue 0.5221699660374175
# outdegrees x indegrees
#   test_pearson: correlation -0.08497252666375642, pvalue 0.40059235530633464
#   test_spearman: correlation -0.07797106321133546, pvalue 0.44065793967583056
#   test_kendall: correlation -0.06106649393063198, pvalue 0.44624725487791894

# %% [markdown]
# **Considerando o artigo da *Vox*, discuta sobre o significado e a significância dos resultados acima.**

# %% [raw]
# O melhor grafico para analisar o p-value é o com correlação quase 1, que é uma linha na vertical perfeita. Este é o grafico do degree/indegrees, e observa-se um p-value quase 0 neste caso (10^-105). Porem, o artigo debate mais sobre os p-values mais "incertos", <0.05 e <0.005.
# Observa-se por exemplo o grafico do degrees/qualitys. Ele não mostrava relação observavel, parecia muito desperço e sem nenhuma relação, entretanto o p-value é <0.05. Alem disso, a correlation é 0.2, o que indica que há "algo" ai fazendo uma leve e quase imperceptivel correlação entre ambas variaveis.

# %% [markdown]
# Se você colocar o arquivo dos dados de Cabreúva na mesma pasta deste notebook, a linha abaixo deve carregá-lo.

# %%
data = pd.read_csv('cabreuva_limpa.csv', encoding='iso-8859-1')

# %% [markdown]
# **Tente fazer uma investigação análoga à investigação acima, mas sobre os dados de Cabreúva. Discuta sobre as diferenças dos resultados e sobre como essas diferenças estão relacionadas à natureza dos dados.**

# %%
data.head()
# Out:
#    Unnamed: 0                   ESCOLA                            NOME TURMA  \
# 0           1  EE ANA MESQUITA LAURINI          ALAN DAVID ALVES SILVA    1D
# 1           2  EE ANA MESQUITA LAURINI             ALAN VIEIRA RIBEIRO    1A
# 2           3  EE ANA MESQUITA LAURINI  ALUAN FIDELIS RIBEIRO DE SOUZA    1B
# 3           4  EE ANA MESQUITA LAURINI           AMANDA APARECIDA GOES    1D
# 4           5  EE ANA MESQUITA LAURINI    ANA BEATRIZ ALVES DOS SANTOS    1D
#
#    IDDEINQUIRIDO DATADEINÍCIO  IDADE  ANODENASCIMENTO       SEXO  \
# 0   4.237477e+09   10/05/2015     16             1999  Masculino
# 1   4.233702e+09   10/02/2015     16             1999  Masculino
# 2   4.233349e+09   10/02/2015     15             1999  Masculino
# 3   4.237431e+09   10/05/2015     16             1999   Feminino
# 4   4.237431e+09   10/05/2015     15             1999   Feminino
#
#                                             RELIGIÃO   ...     escola_short  \
# 0                              Eu não tenho religião   ...              AML
# 1  Religião afro-brasileira (como o Candomblé ou ...   ...              AML
# 2                              Eu não tenho religião   ...              AML
# 3                                     Evangélico (a)   ...              AML
# 4                                       Católico (a)   ...              AML
#
#   serie  eja  idade  grupo_idade  masculino  religion  religiao  raca  corpele
# 0     5    1     16           16          1         6         6     3       11
# 1     5    1     16           16          1         4         4     1        5
# 2     5    1     15           15          1         6         6     1        5
# 3     5    1     16           16          0         2         2     1        7
# 4     5    1     15           15          0         3         3     3        9
#
# [5 rows x 117 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0                                                 int64
# ESCOLA                                                    object
# NOME                                                      object
# TURMA                                                     object
# IDDEINQUIRIDO                                            float64
# DATADEINÍCIO                                              object
# IDADE                                                      int64
# ANODENASCIMENTO                                            int64
# SEXO                                                      object
# RELIGIÃO                                                  object
# EVANGELICO                                                 int64
# RAÇA                                                      object
# CORDEPELE                                                  int64
# BEMCONSIGOMESMO                                            int64
# ACREDITOEMSORTEMAISDOQUETRABALHO                           int64
# ALGOMEIMPEDEDECONQUISTARASCOISAS                           int64
# PLANOSSEMPREDÃOERRADO                                      int64
# INÚTIL                                                     int64
# ACREDITONOSMEUSPLANOS                                      int64
# INCLUSÃODEPORTADORESDEDEFICIÊNCIAEMSALASCOMUNS             int64
# FILHALÉSBICA                                               int64
# TANTOFAZBRANCOSOUNEGROS                                    int64
# IMPORTANTEESCOLASESPECIAISPARAPORTADORESDEDEFICIÊNCIA      int64
# GAYSREVEJAMSUAOPÇÃO                                        int64
# BRANCOSMAISDISCIPLINADOS                                   int64
# ALGUNSGRUPOSTEMMAISVALOR                                   int64
# USARFORÇACONTRAOUTROS                                      int64
# TANTOFAZAMIGOSBRANCOSENEGROS                               int64
# NORMALUMGRUPOTERMAISOPORTUNIDADE                           int64
# GRUPOSSUPERIORESDEVEMCONDUZIR                              int64
#                                                           ...
# PAIADOTIVO                                               float64
# MÃE                                                      float64
# MADRASTA                                                 float64
# MÃEADOTIVA                                               float64
# IRMÃO                                                    float64
# IRMÃ                                                     float64
# AVÓ                                                      float64
# MEUCONJUGE                                               float64
# MEUFILHO                                                 float64
# OUTROSPARENTES                                           float64
# PESSOASQUENÃOSÃOPARENTES                                 float64
# TRABALHODAMÃE                                             object
# TRABALHODOPAI                                             object
# HORASNAINTERNETPARAESTUDAR                                 int64
# HORASNAINTERNETPARACOMUNICAÇÃO                             int64
# HORASNAINTERNETPARAJOGAR                                   int64
# HORASNATELEVISÃO                                         float64
# X                                                         object
# entrevista                                                 int64
# escola                                                     int64
# escola_short                                              object
# serie                                                      int64
# eja                                                        int64
# idade                                                      int64
# grupo_idade                                                int64
# masculino                                                  int64
# religion                                                   int64
# religiao                                                   int64
# raca                                                       int64
# corpele                                                    int64
# Length: 117, dtype: object

# %%
import matplotlib.pyplot as plt
d1 = pd.crosstab(data.EVANGELICO, data.FILHALÉSBICA )
d1.plot(kind = "bar", color =("yellow","blue"), figsize=(20, 6))

# %% [markdown]
# Use as referências abaixo para experimentar outras direções de investigação.
#
# * [Visualizing statistical relationships](https://seaborn.pydata.org/tutorial/relational.html#relational-tutorial);
# * [Plotting with categorical data](https://seaborn.pydata.org/tutorial/categorical.html#categorical-tutorial);
# * [Visualizing the distribution of a dataset](https://seaborn.pydata.org/tutorial/distributions.html#distribution-tutorial).

# %%
sns.set(style="darkgrid")
tips = sns.load_dataset()
sns.catplot(x = "EVANGELICO", y = "FILHALÉSBICA", data=tips);
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-27-a9ac4ba20ea0> in <module>()
#       1 sns.set(style="darkgrid")
# ----> 2 tips = sns.load_dataset("d1")
#       3 sns.catplot(x = "EVANGELICO", y = "FILHALÉSBICA", data=tips);
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# c:\users\leo_v\appdata\local\programs\python\python36-32\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ### Observações
